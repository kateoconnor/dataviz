# %%
import plotly_express as px

# %%
pip install kaleido
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
fig = px.scatter(px.data.gapminder(), x="lifeExp", y="gdpPercap", animation_frame="year", animation_group="country",
           size="pop", color="country", hover_name="country", 
           log_y = True, 
           size_max=45, range_x=[25,90], range_y=[100,100000])
fig.show()

# %%
fig.write_html("gmex.html")

# %%
import plotly.io as pio

# %%
pio.write_html(fig, file='gapmind.html', auto_open=True)
